# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 此刻python已經會了數學

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %% [markdown]
# ### x自動會填入(0,1,2,....)去對應y，並將點相連

# %%
randn(10)
# Out:
# array([-0.26678395, -0.14485063, -1.80831315,  0.7604045 , -0.09163775,
#        -0.96694839,  0.43576658,  0.71811356, -0.12572512, -0.84655009])

# %% [markdown]
# ### numpy亂數指令，從normal(0,1)裡隨機挑10個點

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])

# %% [markdown]
# ### 對應x,y座標
