# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 若要做數據分析，每次打開程式第一個下達指令*3
# # %matplotlib inline
# ### 讓jupyter notebook能夠出現matplotlib的圖片
# ### 以後畫圖可直接將屠城現在網頁下，而不另外呈現
# #### 取代%pylab inline
# #### 偷偷讀進了很多你需要或者不需要的function，混合讀入很多指令
# # pyploy 幫忙畫圖的function

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3,-4,1,5,-2,7,3,-5,6])

# %%
plt.plot(np.random.randn(100))

# %% [markdown]
# ### 平均值0 標準差1的normal distribution

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 用tab鍵可以自動補完剩下的指令
